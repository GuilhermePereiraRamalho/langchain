# %%
texto_completo = """
Python é uma linguagem de programação de alto nível conhecida por sua simplicidade, 
legibilidade e versatilidade. Seu design foi criado com o objetivo de ser fácil de 
aprender e usar, permitindo que programadores escrevam código de maneira mais 
intuitiva e eficiente. Ao contrário de outras linguagens, Python prioriza a 
legibilidade do código, o que facilita a compreensão e manutenção do software, 
mesmo por programadores que não são os autores do código original. 
Sua sintaxe clara, por exemplo, elimina a necessidade de muitos símbolos ou 
palavras-chave complicadas, tornando o código mais próximo da linguagem humana.
"""

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
chunk_size = 50
chunk_overlap = 0
char_split = CharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap
)

# %%
import string
texto = "".join(f"{string.ascii_lowercase}" for _ in range(5))
len(texto)
# Out:
# 130

# %%
texto
# Out:
# 'abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz'

# %%
split = char_split.split_text(texto)
len(split)
# Out:
# 1

# %%
split
# Out:
# ['abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz']

# %%
char_split = CharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    separator=""
)

# %%
split = char_split.split_text(texto)
len(split)
# Out:
# 3

# %%
split
# Out:
# ['abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwx',
#  'yzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuv',
#  'wxyzabcdefghijklmnopqrstuvwxyz']

# %%
chunk_size = 50
chunk_overlap = 0
char_split = CharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    separator=""
)

split = char_split.split_text(texto_completo)
len(split)
# Out:
# 13

# %%
split
# Out:
# ['Python é uma linguagem de programação de alto nív',
#  'el conhecida por sua simplicidade, \nlegibilidade e',
#  'versatilidade. Seu design foi criado com o objeti',
#  'vo de ser fácil de \naprender e usar, permitindo qu',
#  'e programadores escrevam código de maneira mais \ni',
#  'ntuitiva e eficiente. Ao contrário de outras lingu',
#  'agens, Python prioriza a \nlegibilidade do código,',
#  'o que facilita a compreensão e manutenção do softw',
#  'are, \nmesmo por programadores que não são os autor',
#  'es do código original. \nSua sintaxe clara, por exe',
#  'mplo, elimina a necessidade de muitos símbolos ou',
#  'palavras-chave complicadas, tornando o código mai',
#  's próximo da linguagem humana.']

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
chunk_size = 50
chunk_overlap = 10
char_split = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    separators=[".", " ", ""]
)

split = char_split.split_text(texto)
len(split)
# Out:
# 3

# %%
split
# Out:
# ['abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwx',
#  'opqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijkl',
#  'cdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz']

# %%
chunk_size = 250
chunk_overlap = 10
char_split = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    separators=["\n\n","\n", " ", ""]
)

split = char_split.split_text(texto_completo)
len(split)
# Out:
# 3

# %%
split
# Out:
# ['Python é uma linguagem de programação de alto nível conhecida por sua simplicidade, \nlegibilidade e versatilidade. Seu design foi criado com o objetivo de ser fácil de \naprender e usar, permitindo que programadores escrevam código de maneira mais',
#  'intuitiva e eficiente. Ao contrário de outras linguagens, Python prioriza a \nlegibilidade do código, o que facilita a compreensão e manutenção do software, \nmesmo por programadores que não são os autores do código original.',
#  'Sua sintaxe clara, por exemplo, elimina a necessidade de muitos símbolos ou \npalavras-chave complicadas, tornando o código mais próximo da linguagem humana.']

# %%
from langchain_text_splitters import TokenTextSplitter

chunk_size = 50
chunk_overlap = 5
char_split = TokenTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap
)

# %%
split = char_split.split_text(texto)
len(split)
# Out:
# 2

# %%
split
# Out:
# ['abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijklmnopq',
#  'ijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz']

# %%
chunk_size = 250
chunk_overlap = 10
char_split = TokenTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
)

split = char_split.split_text(texto_completo)
len(split)
# Out:
# 1

# %%
split
# Out:
# ['\nPython é uma linguagem de programação de alto nível conhecida por sua simplicidade, \nlegibilidade e versatilidade. Seu design foi criado com o objetivo de ser fácil de \naprender e usar, permitindo que programadores escrevam código de maneira mais \nintuitiva e eficiente. Ao contrário de outras linguagens, Python prioriza a \nlegibilidade do código, o que facilita a compreensão e manutenção do software, \nmesmo por programadores que não são os autores do código original. \nSua sintaxe clara, por exemplo, elimina a necessidade de muitos símbolos ou \npalavras-chave complicadas, tornando o código mais próximo da linguagem humana.\n']

# %%
from langchain_community.document_loaders.pdf import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

chunk_size = 50
chunk_overlap = 10

char_split = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap
)

# %%
arquivo = "files/apostila.pdf"
loader = PyPDFLoader(arquivo)
docs = loader.load()
docs[0]
# Out:
# Document(page_content=' \n  \n \n \n \n \n \n \n \n \nINTRODUÇÃO À PROGRAMAÇÃO \nCOM PYTHON  \n \n \n \n \n \n \n \nPrograma de Educação Tutorial  \nGrupo PET - ADS    \nIFSP -  Câmpus São Carlos  \n \n \n \n \n \n  ', metadata={'source': 'files/apostila.pdf', 'page': 0})

# %%
split = char_split.split_documents(docs)
len(split)
# Out:
# 1129

# %%
split
# Out:
# [Document(page_content='INTRODUÇÃO À PROGRAMAÇÃO', metadata={'source': 'files/apostila.pdf', 'page': 0}),
#  Document(page_content='COM PYTHON', metadata={'source': 'files/apostila.pdf', 'page': 0}),
#  Document(page_content='Programa de Educação Tutorial', metadata={'source': 'files/apostila.pdf', 'page': 0}),
#  Document(page_content='Grupo PET - ADS    \nIFSP -  Câmpus São Carlos', metadata={'source': 'files/apostila.pdf', 'page': 0}),
#  Document(page_content='Sumário', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='PREFÁCIO  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='........................  1', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='1. INTRODUÇÃO  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ ..............', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='2', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='1.1 Característi cas da linguagem Python', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='Python  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ ..... 2', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='1.2 Instalação do interpretador Python', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='Python  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .......  2', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='2. VARIÁVEIS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...................  4', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='3. STRINGS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='......................  6', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='3.1 Concatenação d e strings', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='strings  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='........................  6', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='3.2 Manipulação de strings', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='strings  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='..........................  7', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='3.3 Fatiamento de strings', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='strings  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='............................  8', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='3.4 Exercícios: strings', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='strings  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .. 8', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='4. NÚMEROS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...................  9', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='4.1 Operadores numéricos', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='..........................  9', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='4.2 Exercícios: números', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='números  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...............................  9', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5. LISTAS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='.......................  10', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5.1 Funções para manipulação de listas', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='listas  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .... 10', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5.2 Operações com listas', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='listas  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...........................  11', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5.3 Fatiamento de listas', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='listas  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='............................  11', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5.4 Criação de listas com range ( )', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='( )  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .............', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='12', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='5.5 Exercícios: listas', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='listas  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ ... 12', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='6. TUPLAS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='.....................  13', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='7. DICIONÁRIOS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ ............  13', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='13', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='7.1 Operações em dicionários', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...................  14', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='7.2 Exercícios: dicionários', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='..........................  14', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='8. BIBLIOTECAS  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .............', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='15', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='9. ESTRUTURAS DE DECISÃO', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='DECISÃO  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='.........................  15', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='9.1 Estrutura if', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='if  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ ...........  16', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='9.2 Estrutura if..else', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='if..else  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .. 16', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='9.3 Comando  if..elif ..else', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='..else  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='...........................  16', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='9.4 Exercícios: estruturas de decisão', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='decisão  ................................', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='................................ .........  17', metadata={'source': 'files/apostila.pdf', 'page': 1}),
#  Document(page_content='10. ESTRUTURAS DE REPETIÇÃO', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='...................  17', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='10.1 Laço while  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ..........  17', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='10.2 Laço for  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ..............', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='18', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='10.3 Exercício s: estrutura de repetição', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='repetição ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ...... 19', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11. FUNÇÕES  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='19', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.1 Como definir uma função', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='função  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='..................  19', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.2 Parâmetros e argumentos', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='.................  19', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.3 Escopo das variáveis', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='..........................  20', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.4 Retorno de valores', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='valores  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='............................  20', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.5  Valor padrão', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='padrão  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ...... 21', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='11.6 Exercícios: funções', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='funções ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='.............................  21', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='12. RESPOSTAS DOS EXERCÍCIOS', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='...................  22', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='BIBLIOGRAFIA  ................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='................................ ...............', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='25', metadata={'source': 'files/apostila.pdf', 'page': 2}),
#  Document(page_content='1 \n PREFÁCIO', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Este material foi escrito para ser utilizado em', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='em cursos de extensão de  Introdução à', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Programação com Python , do Instituto Federal de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de Educação, Ciência e Tecnologia de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='São Paulo , câmpus São Carlos.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='A apostila foi desenvolvida pelo s integrantes do', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='do Programa de Educação Tutorial do curso', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de Tecnologia em Análise e Desenvolvimento de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de Sistemas - grupo PET ADS  / IFSP  São', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Carlos. O grupo iniciou suas atividades em 2011 ,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='em 2011 , e realiza atividades diversas', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='diversas  envolvendo', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Ensino, Pesquisa e Extensão.  Entre as linguagens', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='e ferramentas de programação estudadas', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='pelo grupo estão : o ambiente de desenvolvimento', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Lazarus, o editor de jogos Construct 2, as', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='linguagens Ruby, Python e JavaScript, os', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='os frameworks Rails, Django, Web2Py e Grails.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='A linguagem Python s e destacou pela facilidade', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de programação e versatilidade. Python é', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='uma linguagem de uso geral, que pode ser', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='pode ser utilizada para diversas aplicações.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Apresenta', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='uma sintaxe simples, tornando os programas mais', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='mais legíveis, o que também facilita o', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='aprendizado da ling uagem. Possui listas,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='listas, dicionários e tuplas como estruturas de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de dados', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='pré-definidas. É uma linguagem multiparadigma:', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='suporta os paradigmas de programação', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='procedural, funcional e orientado a objetos.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Diversos petianos colaboraram na confecção desta', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='desta apostila.  Mas gostaria de agradecer', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='especialmente quatro estudantes que se destacaram', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='pelo empenho e dedicação na', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='execução dessa tarefa: José Picharillo, Lucas', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Lucas Limão, Viviane Quinaia e Camila Couto.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Este é um material de apoio para um curso de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='curso de extensão introdutório, cujo objetivo é', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='divulgar a linguagem Python. Não é um material', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='material preparado para autoaprendizagem,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='embora seja possível utilizá -lo com esse fim.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Reforçando, este é um material introdutório. Tem', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Tem muit o mais  para aprender em Python:', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='orientação a objetos, programação funcional,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='metaprogramação, interface gráfica,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='expressões regulares, threads, tratamento de', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='de exceções, funções anônimas, geradores,', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='desenvolvimento web, aplicativos móveis, entre', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='entre outr as.', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Bem -vindo ao mundo Python!', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Prof. Dr. João Luiz Franco', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='Tutor do grupo PET - ADS  / São Carlos', metadata={'source': 'files/apostila.pdf', 'page': 3}),
#  Document(page_content='2 \n  \n1. INTRODUÇÃO', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='1.1 Características da l inguagem Python', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='A linguagem de programação Python  foi criada  em', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='em 1991  por Guido V an Rossum em, com a', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='finalidade de ser uma linguagem simpl es e de', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='es e de fácil compreensão. Ape sar de simples,', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='simples, Python é uma', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='linguagem muito poderosa, que pode ser usada para', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='para desenvolver e administrar grandes sistemas.', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='Uma das principais características que diferenci', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='diferenci a a linguagem Python das outras  é a', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='é a legibilidade dos', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='programas escritos . Isto ocorre porque , em', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content=', em outras linguagens , é muito comum o uso', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='o uso  excess ivo de', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='marcações (p onto ou ponto e vírgula ), de', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='), de marcadores ( chaves, colchetes ou parêntes', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='parêntes es) e de', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='palavras especiais  (begin/end), o que torna mais', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='mais  difícil a leitura e compreensão dos', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='dos programas. Já', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='em Python, o uso desses recursos é reduzido,', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='reduzido, deixando  a linguagem visualmente mais', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='mais limpa, de', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='fácil compreensão e leitura.', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='Entre outras características existentes n a', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='n a linguagem P ython, destaca -se a simplicidade', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='da', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='linguagem, que facilita o aprend izado  da', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='izado  da programa ção. Python também possui uma', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='uma portabilidade', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='muito grande para diversas plataformas', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='diferentes, além de ser possível utilizar trechos', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='trechos de código s', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='em outras linguagens .', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='Python é um software livre, ou se ja, permite', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='permite  que usuários e colaboradores possam', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='possam modificar seu', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='código fonte  e compartilhar essas novas', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='novas atualizações , contribuindo  para o', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='para o constante', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='aperfeiçoamento  da linguagem.  A especificação', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='da linguagem é mantida pela empresa Python', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='Software Foundation  (PSF).', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='1.2 Instalação do i nterpretador Python', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='a) Instala ção de  Python  no Linux', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='Nas versões mais recentes do GNU/Linux , o Python', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='o Python já se encontra instalado , bastando ao', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='programador entrar no terminal e digitar python .', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='python . Caso não esteja , segue m os passos para', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='para a', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='instalaç ão no terminal :', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='1. Acesse o terminal Linux.', metadata={'source': 'files/apostila.pdf', 'page': 4}),
#  Document(page_content='3', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='2. Digite o comando sudo  apt-get install', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='install  python3.4 no terminal do GNU/Linux para', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='para inicializar', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='o processo de instalação.', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='3. Terminado o download , o interpretador já', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='já estará instalado no  computador.', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='b) Instalação  do IDLE  no Linux', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='O IDLE é um ambiente in tegrado de', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='de desenvolvimento  que acompanha a instalação do', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='do interpretador', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='Python em sistemas operacionais Windows. Para tê', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='Para tê -lo disponível em distribuições Linux', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='Linux basta', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='seguir as e tapas abaixo:', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='1. Acesse o t erminal Linux .', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='2. Digite o comando sudo  apt-get install', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='install idle-python3.4 .', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='3. Para executá -lo basta digitar no terminal', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='terminal idle-python3.4 & .', metadata={'source': 'files/apostila.pdf', 'page': 5}),
#  Document(page_content='4 \n c) Instala ção do  Python  no Windows', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='A instalação do interpretador Python para Windows', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Windows é mais simples,  conforme apresentado a', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='a seguir :', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='1. Entre no site www.python.org . Na aba', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='. Na aba  download  selecione  a versão 3.5.1 .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='2. Após o download , execute o instalador', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='mantendo , por default , todas as configurações a', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='a cada', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='passo da instalação. Depois clique em Finalizar', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='e o interpretador Python já est ará instalado', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='no computador.', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Caso  você não consiga  execut ar o interpretador', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Python pelo prompt de comando , provavelmente o', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='path não está configurado. Veja abaixo os passos', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='os passos para configurá -lo:', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='1. Com o cursor do mouse vá até Computador ,', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content=', clique  com o botão direito e escolha', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Propriedades .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='2. Depois clique em Configurações avançadas do', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='do sistema  e, a seguir , Variáveis  de ambiente', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='ambiente .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='3. Com ajuda  da barra de rolagem  procure a', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='a  variável chamada path, selecion e-a e escolha', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='e escolha a', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='opção Editar .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='4. Na próxima janela , no campo Valor de variável', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='variável , você irá encontrar uma lista contendo', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='vários paths  de outros programas. Para adicionar', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='adicionar um novo path, vá até o final da lista e', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='lista e', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='acrescente um ponto e vírgula  ( ; ). Depois', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='). Depois disso , copie  o endereço da pasta onde', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='onde se', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='enco ntra instalado o interpretador P ython e c', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='ython e c ole após ponto e vírgula .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='2. V ARIÁVEIS', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Variáveis são pequenos espaços de memória,', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='memória, utilizados para armazenar e manipular', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='manipular dados. Em', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Python, os tipos de dados básicos  são:  tipo', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='tipo inteiro (armazena números inteiros ), tipo', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='), tipo float (armazena', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='números em formato decimal ), e tipo string', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='string (armazena um conjun to de caracteres).', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Cada variável', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='pode armazenar apenas um tipo de dado  a cada', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='a cada instante .', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Em Python, diferente mente  de outras linguagens', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='de programação, não é preciso declarar de que', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='de que tipo', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='será cada v ariável no início do programa. Q', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Q uando se faz uma atribuição  de valor ,', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='valor , automaticamente a', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='variável se torna do tipo do valor armazenado,', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='como apresentado  nos exemplos a seguir :', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='Exemplos:', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='A variável a se torna uma variável do tipo', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='do tipo inteiro.', metadata={'source': 'files/apostila.pdf', 'page': 6}),
#  Document(page_content='5', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='A variável b se torna uma variável do tipo float.', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='float.', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='A variável c se torna  uma variável do tipo', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='do tipo string.', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='A atribuição de valor para uma variável pode ser', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='pode ser feita utiliza ndo o comando input( ),', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='input( ), que', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='solicita ao usuário o valor a  ser atribuído à', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='à variável .', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='Exemplo:', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='O comando input() , sempre vai retornar uma s', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='uma s tring. Nesse caso, para retornar dados do', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='dados do tipo', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='inteiro ou float, é preciso converter o tipo do', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='o tipo do valor lido . Para isso, utiliza -se o', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='-se o int (string ) para', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='converter para o  tipo inteiro, ou float  (string', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='(string ) para converter para o  tipo float.', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='Exemplo s:', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='Em Python, os nomes da s variáveis devem ser', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='devem ser inicia dos com uma letra, mas podem', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='mas podem possuir outros', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='tipos de caracteres , como números e símbolos. O', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='O símbolo sublinha ( _ ) também é aceito no', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='aceito no início', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='de nomes de variáveis.', metadata={'source': 'files/apostila.pdf', 'page': 7}),
#  Document(page_content='6', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Tabela 1  - Exemplos de nomes v álidos e', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='álidos e inválidos', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Nome   \nVálido   \nComentários', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='a3 Sim Embora contenha um número, o nome a 3', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='nome a 3 inicia com letra.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='velocidade  Sim Nome formado com letras.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='velocidade90  Sim Nome formado por letras e', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='letras e números, mas inicia com letras.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='salario_mé dio Sim O símbolo ( _  ) é permitido e', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='e facilita a leitura de nomes grandes.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='salario médio  Não Nomes de variáveis não podem', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='não podem conter espaços em branco.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='_salário  Sim O sublinha ( _ ) é aceito em nomes', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='em nomes de variáveis, mesmo no início.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='5A Não Nomes de variáveis não podem começar com', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='com  números.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='3. STRINGS', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Uma string é uma sequência de caracteres simples.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='simples.  Na linguagem Python, as strings são', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='são utilizadas', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content="com aspas simples ( '... ') ou aspas duplas (", metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='duplas ( "...").', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Para exibir uma string , utiliza -se o comando', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='o comando print().', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Exemplo:', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='3.1 Concatenação de strings', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Para c oncatena r strings, utiliza -se o operador', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='operador +.', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='Exemplo:', metadata={'source': 'files/apostila.pdf', 'page': 8}),
#  Document(page_content='7 \n 3.2 Manipulação  de strings', metadata={'source': 'files/apostila.pdf', 'page': 9}),
#  Document(page_content='Em Python, existem vária s funções (métodos) para', metadata={'source': 'files/apostila.pdf', 'page': 9}),
#  Document(page_content='para manipular strings .  Na tabela a seguir  são', metadata={'source': 'files/apostila.pdf', 'page': 9}),
# ...
#  Document(page_content='A repetição está associada  ou a uma condição ,', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content=', que indica se deve continuar ou não a', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='ou não a repetição,  ou a', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='uma sequência de valores , que determina quantas', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='quantas  vezes a sequência deve ser  repetid a.', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='a. As estruturas', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='de repetição são conhecidas também como  laços', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='laços (loops ).', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='10.1 Laço w hile', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='No laço  while, o trecho de código da repetição', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='repetição está associado a  uma condição .', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='. Enquanto a condição', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='tiver valor verdadeiro , o trecho é executado.', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='Quando a condição passa a ter valor falso , a', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='falso , a repetição', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='termina.  \n \nSintaxe:  \n while <condição>  :', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='<Bloc o de comandos > \n \nExemplo:', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='senha = "54321"  \nleitura =" "', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='while (leitura != senha):', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='leitura = input("Digite a senha: ")', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='if leitura == senha :', metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content="print('Acesso liberado ')  \n   else:", metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content="print('Senha incorreta. Tente novamente')", metadata={'source': 'files/apostila.pdf', 'page': 19}),
#  Document(page_content='18 \n Digite a senha:  abcde', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Senha incorreta. Tente novamente', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Digite a senha:  12345', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Senha incorreta. Tente novamente', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Digite a senha:  54321 \nAcesso liberado', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Exemplo:  Encontrar a soma de 5 valores.', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='contador = 0  \nsomador = 0', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='while contador < 5:', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='contador  = contador + 1', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content="valor = float(input('Digite o '", metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content="o ' +str(contador)+ 'º valor: ' ))", metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='somador = somador + valor', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content="print('Soma = ' , somador)  \n \n10.2 Laço f or", metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='O laço for é a estrutura de repetição mais', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='mais utilizada em Python . Pode ser utilizado com', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='com uma', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='sequência numérica (gerada com o comando range )', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='range ) ou associado a uma lista. O trecho de', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='trecho de código da', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='repetição  é executado para cada valor da', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='valor da sequência numérica ou da lista.', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Sintaxe:', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='for <variável > in range  (início , limite, pass', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='pass o):', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='<Bloco de comandos >  \nou', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='ou \n for <variável>  in  <lista>  :', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='<Bloco de comandos >  \n \n \nExemplo s:', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='1. Encontrar a soma S = 1+4+7+10+13+16+19', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='S=0 \nfor x in range(1,20,3):  \n    S = S+x', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content="print('Soma = ' ,S)", metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='2. As notas de um aluno estão armazenadas em uma', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='em uma lista. Calcular a média dessas notas.', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='Lista_notas= [3.4,6.6,8,9,10,9.5,8.8,4.3]', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='soma=0 \nfor nota in Lista_notas :', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='soma = soma+nota', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='média = soma/ len(Lista_notas)', metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content="print('Média = ', média)", metadata={'source': 'files/apostila.pdf', 'page': 20}),
#  Document(page_content='19 \n 10.3 Exercícios : estrutura de repetição', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='1 - Escreva  um programa para encontrar a soma S', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='a soma S = 3 + 6 + 9 +  …. + 333 .', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='2 – Escreva  um programa que leia 10 notas e', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='notas e informe a média dos alunos.', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='3 – Escreva  um programa que leia um número de 1', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='de 1 a 10, e mostre a tabuada desse número.', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='11. FUNÇÕES', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Funções são pequenos trechos de código', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='de código reutilizáveis. Elas permitem dar um', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='dar um nome a um bloco de', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='comandos e executar  esse bloco, a partir de', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='partir de qualquer lugar do programa .', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='11.1 Como definir  uma função', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Funções são definidas usando a palavra -chave', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='-chave  def, conforme sintaxe a seguir :', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='def  <nome_função> (<definição dos parâmetros', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='>) :', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='<Bloco de comandos da função>', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Obs.: A definição dos parâmetro s é opcional .', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Exemplo: Função simples  \n \ndef hello():', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='print ("Olá Mundo!!!" )', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Para usar a função, basta chamá-la pelo nome:', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='>>> hello()  \nOlá Mundo!!!', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='11.2 Parâmetros e a rgumentos', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Parâmetros são as variáveis que podem ser', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='podem ser incluídas nos parênteses das funções .', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='funções . Quando a', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='função é chamada são passados valores para essas', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='essas variáveis. E sses valores são chamados', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='argumentos. O corpo da função pode utilizar essas', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='essas variáveis, cujos valores podem modificar o', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='comportamento da função.', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='Exemplo:  Função para imprimir  o maior entre 2', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='entre 2 valores', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='def maior(x,y): \n    if x>y: \n        print(x)', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='else: \n        print(y) \n \n>>> maior(4,7)', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='7', metadata={'source': 'files/apostila.pdf', 'page': 21}),
#  Document(page_content='20 \n 11.3 Escopo das variáveis', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Toda  variável utilizada  dentro de uma função', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='função  tem escopo local, isto é, ela não será', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='não será acessível por', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='outras funções ou pelo programa principal.  Se', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Se houver variável com o mesmo nome fora da', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='fora da função,', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='será uma outra variável, completamente', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='independentes entre si .', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Exemplo:  \n \ndef soma(x,y): \n    total = x+y', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='print("Total soma = " ,total)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='#programa principal  \ntotal = 10  \nsoma(3,5)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='print("Total principal = " ,total)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='\uf0e0 Resultado da execução:  \nTotal soma = 8', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Total principal = 10', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Para uma variável ser compartilhada entre', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='entre diversas funções e o programa principal,', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='ela deve ser', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='definida como variável global . Para isto,', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='isto, utiliza -se a instrução  global  para', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='para declarar  a variável em', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='todas as funções para as quais ela deva estar', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='estar acessível . O mesmo vale para o programa', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='programa principal.', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Exemplo:  \ndef soma(x,y): \n  global total', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='total = x+y', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='print("Total soma = " ,total)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='#programa principal  \nglobal total', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='total = 10  \nsoma(3,5)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='print("Total principal = " ,total)', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='\uf0e0 Resultado da execução:  \nTotal soma = 8', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Total principal = 8  \n \n11.4 Retorno de valores', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='O comando  return  é usado para retornar um valor', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='um valor de uma função  e encerrá -la. Caso não', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='Caso não seja', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='declarado um valor de retorno, a função retorna', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  Document(page_content='retorna  o valor None  (que significa nada, sem', metadata={'source': 'files/apostila.pdf', 'page': 22}),
#  ...]
