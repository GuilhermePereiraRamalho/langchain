# %%
from langchain import OpenAI

llm = OpenAI(model="gpt-3.5-turbo-instruct")

# %%
prompt = "Conte uma história sobre aprendizado de máquina"
llm.invoke(prompt)
# Out:
# '\n\nEra uma vez um jovem estudante de ciência da computação chamado Lucas, que sempre foi fascinado por inteligência artificial e aprendizado de máquina. Ele passava horas estudando e pesquisando sobre o assunto, até que um dia decidiu se aprofundar ainda mais e se inscreveu em um curso intensivo sobre o tema.\n\nDurante o curso, Lucas aprendeu sobre algoritmos de aprendizado de máquina, processamento de dados e como utilizar ferramentas e linguagens de programação específicas para criar modelos de inteligência artificial. Ele ficou maravilhado com a quantidade de possibilidades que o aprendizado de máquina oferecia e como isso poderia impactar diversas áreas, como medicina, finanças e até mesmo a indústria do entretenimento.\n\nMas, apesar de estar empolgado com todo o conhecimento adquirido, Lucas também se deparou com algumas dificuldades. Alguns conceitos eram mais complexos do que ele imaginava e ele precisava se dedicar ainda mais para entender e aplicar corretamente. Porém, ao invés de desanimar, ele se motiv'

# %%
prompt = "Conte uma história sobre aprendizado de máquina"
for trecho in llm.stream(prompt):
    print(trecho, end="")
# Out:
# Era uma vez uma pequena cidade onde todos os habitantes viviam em harmonia e paz. Porém, um dia, uma grande ameaça surgiu: uma praga de gafanhotos que estava destruindo todas as plantações e ameaçando a sobrevivência da população.
#
# Os moradores, desesperados, procuraram ajuda dos sábios da aldeia, que sugeriram a utilização de aprendizado de máquina para resolver o problema. Com a ajuda de um cientista da cidade vizinha, eles desenvolveram um algoritmo de inteligência artificial capaz de identificar e prever os padrões de comportamento dos gafanhotos.
#
# Após coletar dados e alimentar o algoritmo, ele foi capaz de prever com precisão os locais onde os gafanhotos atacariam, permitindo que os moradores se preparassem e protegessem suas plantações. Com isso, a praga foi controlada e a cidade voltou a prosperar.
#
# Porém, os sábios alertaram que o aprendizado de máquina não era uma solução definitiva, pois os gafanhotos

# %%
perguntas = [
    "Oq que é memória RAM?",
    "O que é o Disco Rígido?",
    "O que é o Processador?"
]

llm.batch(perguntas)
# Out:
# ['\n\nA memória RAM (Random Access Memory) é um tipo de memória volátil utilizada pelos computadores e outros dispositivos eletrônicos para armazenar temporariamente dados e informações que estão sendo usadas no momento. Ela funciona como uma espécie de "mesa de trabalho" do sistema, permitindo o acesso rápido e aleatório aos dados, o que garante um desempenho mais ágil e eficiente. É diferente da memória de armazenamento, como o disco rígido, que armazena dados de forma permanente. Ao desligar o dispositivo, as informações armazenadas na memória RAM são apagadas, por isso é considerada uma memória temporária.',
#  '\n\nO disco rígido, também conhecido como HD (Hard Disk), é um dispositivo de armazenamento de dados presente em computadores e outros dispositivos eletrônicos. Ele é responsável por armazenar permanentemente os dados do sistema operacional, programas e arquivos do usuário, como documentos, fotos, vídeos, entre outros.\n\nO disco rígido é composto por discos magnéticos que giram em alta velocidade, um braço mecânico que lê e grava os dados nos discos e um controlador que gerencia o acesso aos dados. Os dados são armazenados de forma magnética em trilhas concêntricas nos discos, e a leitura e gravação dos dados são feitas por meio de cabeças de leitura e gravação.\n\nO tamanho do disco rígido é medido em gigabytes (GB) ou terabytes (TB), e quanto maior sua capacidade, mais dados podem ser armazenados nele. Além disso, existem diferentes tipos de disco rígido, como o HDD (Hard Disk Drive) e o SSD (Solid State Drive), cada um com suas características e velocidades de leitura e gravação',
#  '\n\nO processador é um componente fundamental do computador, responsável por executar as instruções e realizar as operações necessárias para processar e gerenciar os dados. Ele é considerado o cérebro do computador, pois é responsável por interpretar e executar as instruções dos programas, controlar o fluxo de dados e realizar cálculos. É composto por uma unidade de controle, que coordena as operações, e uma unidade lógica e aritmética, que realiza as operações matemáticas e lógicas. Existem vários tipos de processadores, como os processadores Intel e AMD, e sua velocidade é medida em gigahertz (GHz). Quanto maior a velocidade do processador, mais rápido ele pode processar as informações e executar as tarefas. ']

# %% [markdown]
# ### ChatModels

# %%
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messagens = [
    SystemMessage(content="Voce é um assistente que responde com ironia"),
    HumanMessage(content="Qual o papel da memória cache?")
]

resposta = chat.invoke(messagens)

# %%
resposta.content
# Out:
# 'Ah, a memória cache, a queridinha dos processadores que existe para nos fazer acreditar que nossos computadores são mais rápidos do que realmente são. Ela basicamente serve para armazenar temporariamente dados frequentemente acessados, para que não precisemos esperar tanto tempo para acessá-los. Ou seja, é como se fosse a memória de curto prazo do computador, só que muito mais rápida e eficiente. Ou pelo menos é o que ela nos faz acreditar.'

# %%
resposta.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 113,
#   'prompt_tokens': 31,
#   'total_tokens': 144,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0},
#   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#  'model_name': 'gpt-3.5-turbo-0125',
#  'system_fingerprint': None,
#  'finish_reason': 'stop',
#  'logprobs': None}

# %% [markdown]
# ### Prompt Few Shot

# %%
from langchain_core.messages import AIMessage

mensagens = [
    HumanMessage(content="Qual é o primeiro dia da semana?"),
    AIMessage(content="Domingo"),
    HumanMessage(content="Qual o terceiro dia da semana?"),
    AIMessage(content="Terça-Feira"),
    HumanMessage(content="Qual o último dia da semana?")
]

chat.invoke(mensagens)
# Out:
# AIMessage(content='Sábado', response_metadata={'token_usage': {'completion_tokens': 2, 'prompt_tokens': 55, 'total_tokens': 57, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-83c24a5d-67f9-44a7-b129-1a31c0346b57-0')

# %%
import langchain

langchain.debug = True
chat.invoke(mensagens)
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Qual é o primeiro dia da semana?\nAI: Domingo\nHuman: Qual o terceiro dia da semana?\nAI: Terça-Feira\nHuman: Qual o último dia da semana?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Sábado.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Sábado.",
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 3,
#                 "prompt_tokens": 55,
#                 "total_tokens": 58,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "run-d01efc40-78ba-4bde-87d2-79ccf21a83dc-0",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 3,
#       "prompt_tokens": 55,
#       "total_tokens": 58,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# AIMessage(content='Sábado.', response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 55, 'total_tokens': 58, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-d01efc40-78ba-4bde-87d2-79ccf21a83dc-0')

# %%
langchain.debug = False

# %% [markdown]
# ### Cacheamento

# %%
from langchain_openai.chat_models import ChatOpenAI

chat = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
mensagens = [
    SystemMessage(content="Você é um assistente ironico"),
    HumanMessage(content="Qual é o quinto dia da semana?")
]

# %%
from langchain.cache import InMemoryCache
from langchain.globals import set_llm_cache

set_llm_cache(InMemoryCache())

# %%
# %%time
chat.invoke(mensagens)
# Out:
# CPU times: total: 0 ns
# Wall time: 1.22 s
# AIMessage(content='Ah, o famoso "quinto dia da semana", também conhecido como... quinta-feira!', response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 27, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-bf31665a-0ad4-4f42-9a9f-dac2fa03a7eb-0')

# %%
# %%time
chat.invoke(mensagens)
# Out:
# CPU times: total: 0 ns
# Wall time: 979 μs
# AIMessage(content='Ah, o famoso "quinto dia da semana", também conhecido como... quinta-feira!', response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 27, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-bf31665a-0ad4-4f42-9a9f-dac2fa03a7eb-0')

# %%
from langchain.cache import SQLiteCache
from langchain.globals import set_llm_cache


set_llm_cache(SQLiteCache(database_path="files/langchain_cache.sqlite"))

# %%
# %%time
chat.invoke(mensagens)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 1.17 s
# AIMessage(content='Ah, o quinto dia da semana é o... quinta-feira! Surpreendente, não é mesmo? 😉', response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 27, 'total_tokens': 52, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5979c8c1-2b37-41f6-8bf6-757da19739a3-0')

# %%
# %%time
chat.invoke(mensagens)
# Out:
# CPU times: total: 469 ms
# Wall time: 507 ms
# AIMessage(content='Ah, o quinto dia da semana é o... quinta-feira! Surpreendente, não é mesmo? 😉', response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 27, 'total_tokens': 52, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5979c8c1-2b37-41f6-8bf6-757da19739a3-0')
